# %%
import math
import numpy as np
import pandas as pd
from numpy.random import randn
# This line allows plots to show in the Jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import rcParams
import io
import requests

# %%
import pandas as pd

inside= pd.read_csv ('inside1.csv')
print (inside)
# Out:
#              Time  Temperature   Humidity     Pressure   Altitude   PM1  PM2  \
# 0    1.630652e+09    24.442773  37.162822  1003.997369  77.340272     0    1
# 1    1.630652e+09    24.458008  37.357733  1004.003998  77.140844     0    1
# 2    1.630652e+09    24.463281  37.232881  1004.000213  77.261197     0    1
# 3    1.630652e+09    24.473437  37.302946  1004.005284  77.135268     0    1
# 4    1.630652e+09    24.483594  37.193025  1004.010542  77.248886     0    1
# ..            ...          ...        ...          ...        ...   ...  ...
# 253  1.630652e+09    24.386523  36.902790  1003.969272  77.239838     0    1
# 254  1.630652e+09    24.391602  36.992691  1004.009952  77.253740     0    1
# 255  1.630652e+09    24.391602  37.082633  1003.982531  77.123822     0    1
# 256  1.630652e+09    24.391602  36.972770  1004.011896  77.351057     0    1
# 257  1.630652e+09    24.401758  37.037662  1004.003322  77.346263     0    1
#
#      PM3
# 0      2
# 1      2
# 2      2
# ...

# %%
outside=pd.read_csv('outside1.csv')
print(outside)
# Out:
#              Time  Temperature   Humidity     Pressure   Altitude   PM1  PM2  \
# 0    1.630654e+09    23.644336  34.429298  1002.824241  87.140250  7168    0
# 1    1.630654e+09    23.613672  34.554111  1002.805308  87.202197  7168    0
# 2    1.630654e+09    23.572852  34.474293  1002.799432  87.193103  7168    0
# 3    1.630654e+09    23.511328  34.549208  1002.796592  87.369711  7168    0
# 4    1.630654e+09    23.378320  34.484444  1002.829777  87.367610  7168    0
# ..            ...          ...        ...          ...        ...   ...  ...
# 253  1.630654e+09    21.837891  37.288433  1002.807327  87.163347  7168    0
# 254  1.630654e+09    21.781641  37.283191  1002.794121  87.288025  7168    0
# 255  1.630654e+09    21.791992  37.337894  1002.800725  87.468177  7168    0
# 256  1.630654e+09    21.812305  37.129373  1002.801386  87.290808  7168    0
# 257  1.630654e+09    21.822656  37.367824  1002.793133  87.468200  7168    0
#
#      PM3
# 0    256
# 1    256
# 2    256
# ...

# %%
inside['Temperature'].plot()
plt.
plt.ylabel('Temp')
plt.xlabel('Time')
plt.title('TempxTime')
# Out:
# Text(0.5, 1.0, 'TempxTime')

# %%
inside['Humidity'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['Pressure'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['Altitude'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['PM2'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['PM3'].plot()
# Out:
# <AxesSubplot:>

# %%
outside['Temperature'].plot()
# Out:
# <AxesSubplot:>

# %%
outside['Humidity'].plot()
# Out:
# <AxesSubplot:>

# %%
outside['Pressure'].plot()
# Out:
# <AxesSubplot:>

# %%
outside['Altitude'].plot()
# Out:
# <AxesSubplot:>

# %%
outside['PM2'].plot()
# Out:
# <AxesSubplot:>

# %%
outside['PM3'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.hist(inside.Temperature);
plt.ylabel('Time')
plt.xlabel('Temperature')
plt.title('TempxTime')
plt.show()

# %%
plt.hist(inside.Humidity);
plt.ylabel('Time')
plt.xlabel('Humidity')
plt.title('HumxTime')
plt.show()

# %%
plt.hist(inside.Pressure);
plt.ylabel('Time')
plt.xlabel('Pressure')
plt.title('PressxTime')
plt.show()

# %%
plt.hist(inside.Altitude);
plt.ylabel('Time')
plt.xlabel('Altitude')
plt.title('AltxTime')
plt.show()

# %%
plt.hist(inside.PM2);
plt.ylabel('Time')
plt.xlabel('PM2')
plt.title('PM2xTime')
plt.show()

# %%
plt.hist(inside.PM3);
plt.ylabel('Time')
plt.xlabel('PM3')
plt.title('PM3xTime')
plt.show()

# %%
plt.hist(outside.Temperature);
plt.ylabel('Time')
plt.xlabel('Temperature')
plt.title('TempxTime')
plt.show()

# %%
plt.hist(outside.Humidity);
plt.ylabel('Time')
plt.xlabel('Humidity')
plt.title('HumxTime')
plt.show()

# %%
plt.hist(outside.Pressure);
plt.ylabel('Time')
plt.xlabel('Pressure')
plt.title('PressxTime')
plt.show()

# %%
plt.hist(outside.Altitude);
plt.ylabel('Time')
plt.xlabel('Altitude')
plt.title('AltxTime')
plt.show()

# %%
plt.hist(outside.PM2);
plt.ylabel('Time')
plt.xlabel('PM2')
plt.title('PM2xTime')
plt.show()

# %%
plt.hist(outside.PM3);
plt.ylabel('Time')
plt.xlabel('PM3')
plt.title('PM3xTime')
plt.show()

# %%
print(inside['Temperature'].mean())
# Out:
# 24.502360404554267

# %%
print(inside['Humidity'].mean())
# Out:
# 36.88529728094477

# %%
print(inside['Pressure'].mean())
# Out:
# 1004.0103120964209

# %%
print(inside['Altitude'].mean())
# Out:
# 77.18252244583712

# %%
print(inside['PM2'].mean())
# Out:
# 1.0

# %%
print(inside['PM3'].mean())
# Out:
# 2.0

# %%
print(outside['Temperature'].mean())
# Out:
# 21.88649618459301

# %%
print(outside['Humidity'].mean())
# Out:
# 37.58154825087807

# %%
print(outside['Pressure'].mean())
# Out:
# 1002.8065561568791

# %%
print(outside['Altitude'].mean())
# Out:
# 87.24871653628419

# %%
print(outside['PM2'].mean())
# Out:
# 0.0

# %%
print(outside['PM3'].mean())
# Out:
# 264.93023255813955

# %%
inside['Temperature'].plot()
outside['Temperature'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['Humidity'].plot()
outside['Humidity'].plot()
plt.ylabel('Humidity')
plt.xlabel('Time')
plt.title('HumitityxTime')
# Out:
# Text(0.5, 1.0, 'HumitityxTime')

# %%
inside['Pressure'].plot()
outside['Pressure'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['Altitude'].plot()
outside['Altitude'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['PM2'].plot()
outside['PM2'].plot()
# Out:
# <AxesSubplot:>

# %%
inside['PM3'].plot()
outside['PM3'].plot()
# Out:
# <AxesSubplot:>

# %%
print(inside.std())
# Out:
# Time           87.244479
# Temperature     0.089374
# Humidity        0.153228
# Pressure        0.019785
# Altitude        0.185890
#  PM1            0.000000
# PM2             0.000000
# PM3             0.000000
# dtype: float64

# %%
 print(inside['Temperature'].std())
# Out:
# 0.0893738887716275

# %%
 print(inside['Temperature'].mean())
# Out:
# 24.502360404554267

# %%
inside.loc[:,"Temperature"].std()
# Out:
# 0.0893738887716275

# %%
outside.loc[:,"Temperature"].std()
# Out:
# 0.4010913009326732
